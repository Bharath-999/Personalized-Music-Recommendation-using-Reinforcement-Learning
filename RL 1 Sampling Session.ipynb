# %%
import glob
import pandas as pd
import numpy as np

# %%
data_file_list = glob.glob("Data/training_set/*")
session_data_df = pd.read_csv(data_file_list[1])
session_data_df.head()
# Out:
#                                session_id  session_position  session_length  \
# 0  1_00001238-3f7a-4fd2-b52e-af4237a41ed9                 1              20
# 1  1_00001238-3f7a-4fd2-b52e-af4237a41ed9                 2              20
# 2  1_00001238-3f7a-4fd2-b52e-af4237a41ed9                 3              20
# 3  1_00001238-3f7a-4fd2-b52e-af4237a41ed9                 4              20
# 4  1_00001238-3f7a-4fd2-b52e-af4237a41ed9                 5              20
#
#                            track_id_clean  skip_1  skip_2  skip_3  \
# 0  t_91eb6576-0f1f-4394-92d8-560d7b8f632b    True    True    True
# 1  t_338cb0f3-0035-418f-ab2d-3f9342815aaa    True    True    True
# 2  t_98e73634-8f33-4275-b544-3451553f431e   False    True    True
# 3  t_2fd6279a-06cd-4d5d-9e54-1912f51bb3c3   False   False   False
# 4  t_de860a61-bb57-4386-9d5a-6ba111c4c266   False   False   False
#
#    not_skipped  context_switch  no_pause_before_play  ...  \
# ...

# %%
list(session_data_df.columns)
# Out:
# ['session_id',
#  'session_position',
#  'session_length',
#  'track_id_clean',
#  'skip_1',
#  'skip_2',
#  'skip_3',
#  'not_skipped',
#  'context_switch',
#  'no_pause_before_play',
#  'short_pause_before_play',
#  'long_pause_before_play',
#  'hist_user_behavior_n_seekfwd',
#  'hist_user_behavior_n_seekback',
#  'hist_user_behavior_is_shuffle',
#  'hour_of_day',
#  'date',
#  'premium',
#  'context_type',
#  'hist_user_behavior_reason_start',
#  'hist_user_behavior_reason_end']

# %%
def sample_data(filename, sample_size):
    df = pd.read_csv(filename)
    twenty_session_length_session_ids = df[df['session_length'] == 20].session_id.unique()
    random_sampled_session_ids = np.random.choice(twenty_session_length_session_ids, sample_size, False)
    sampled_df = df[df.session_id.isin(random_sampled_session_ids)]
    return sampled_df

# %%
from tqdm import tqdm
sampled_batch_df = pd.DataFrame(columns = session_data_df.columns)
sample_size = int(10000/len(data_file_list))
for file_name in tqdm(data_file_list):
    sampled_batch_df = sampled_batch_df.append(sample_data(file_name, sample_size))
sampled_batch_df.head()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 66/66 [15:43<00:00, 14.29s/it]
#                                   session_id session_position session_length  \
# 3885  0_00509dce-46e9-4f64-82c9-0229e180f4f8                1             20
# 3886  0_00509dce-46e9-4f64-82c9-0229e180f4f8                2             20
# 3887  0_00509dce-46e9-4f64-82c9-0229e180f4f8                3             20
# 3888  0_00509dce-46e9-4f64-82c9-0229e180f4f8                4             20
# 3889  0_00509dce-46e9-4f64-82c9-0229e180f4f8                5             20
#
#                               track_id_clean skip_1 skip_2 skip_3 not_skipped  \
# 3885  t_6f915f87-0d18-40c0-8d48-a19281b5ac51   True   True   True       False
# 3886  t_0bc988d0-10b8-4581-914b-f4d36f57e1c0   True   True   True       False
# 3887  t_5b8af208-fbd5-4b05-9661-d14c982f13a8   True   True   True       False
# ...

# %%
sampled_batch_df.shape
# Out:
# (199320, 21)

# %%
sampled_batch_df.to_csv(r'D:\Recommendation RL\Code\Data\sampled_data_files\sampled_data.csv', index=False)
